# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.io.json._normalize import nested_to_record

# %matplotlib inline

# %%
username = "lavender"
project_name = "new_manhattan_vs_brooklyn-fixed-label"
sample_name = "data/num_train_samples"
locations = ["manhattan", "brooklyn"]
metric_name = [f"test/{loc}/roc_auc" for loc in locations]
temporal_metric_name = [f"test/{loc}/temporal_roc_auc" for loc in locations]
loss_name = "test/loss"
temporal_loss_name = "test/temporal_loss"
pretrained_names = ["brooklyn", "tisch"]

# %%
import wandb

api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs(f"{username}/{project_name}")
summary_list = []
config_list = []
name_list = []
for run in runs:
    # run.summary are the output key/values like accuracy.
    # We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # run.config is the input metrics.
    # We remove special values that start with _.
    conf = nested_to_record(run.config, sep="/")
    config = {k: v for k, v in conf.items() if not k.startswith("_")}
    config_list.append(config)

    # run.name is the name of the run.
    name_list.append(run.name)

import pandas as pd

summary_df = pd.DataFrame.from_records(summary_list)
config_df = pd.DataFrame.from_records(config_list)
name_df = pd.DataFrame({"name": name_list})
all_df = pd.concat([name_df, config_df, summary_df], axis=1)

# %%
stats = all_df[
    [
        "pretrained",
        "finetuned",
        "test/brooklyn/temporal_roc_auc",
        "test/brooklyn/roc_auc",
        "test/manhattan/temporal_roc_auc",
        "test/manhattan/roc_auc",
        sample_name,
    ]
]
stats.to_csv("Fig3cd.csv")
stats
# Out:
#    pretrained  finetuned  test/brooklyn/temporal_roc_auc  \
# 0   all_sites  manhattan                        0.779699
# 1   all_sites   brooklyn                        0.804892
# 2   all_sites  manhattan                        0.794626
# 3   all_sites   brooklyn                        0.817378
# 4   all_sites  manhattan                        0.800225
# 5   all_sites  manhattan                        0.798773
# 6   all_sites   brooklyn                        0.812011
# 7    brooklyn   brooklyn                        0.798853
# 8    brooklyn  manhattan                        0.784049
# 9   manhattan   brooklyn                        0.807531
# 10  manhattan  manhattan                        0.782217
# 11   brooklyn   brooklyn                        0.785770
# 12   brooklyn  manhattan                        0.783566
# 13  manhattan   brooklyn                        0.801943
# 14  manhattan  manhattan                        0.785009
# 15   brooklyn   brooklyn                        0.804440
# 16   brooklyn  manhattan                        0.790435
# 17  manhattan   brooklyn                        0.808617
# 18  manhattan  manhattan                        0.787432
# 19   brooklyn   brooklyn                        0.794711
# 20   brooklyn  manhattan                        0.783204
# 21  manhattan   brooklyn                        0.803102
# 22  manhattan  manhattan                        0.788999
# 23   brooklyn   brooklyn                        0.798596
# 24   brooklyn  manhattan                        0.795984
# 25  manhattan   brooklyn                        0.806252
# 26  manhattan  manhattan                        0.788109
# 27  all_sites   brooklyn                        0.815287
# 28  all_sites  manhattan                        0.783704
#
#     test/brooklyn/roc_auc  test/manhattan/temporal_roc_auc  \
# 0                0.827747                         0.814015
# 1                0.845732                         0.808016
# 2                0.821461                         0.815204
# 3                0.843731                         0.809234
# 4                0.831433                         0.820215
# 5                0.827032                         0.818480
# 6                0.840594                         0.810536
# 7                0.844475                         0.788279
# 8                0.824363                         0.812227
# 9                0.840007                         0.806726
# 10               0.825810                         0.817818
# 11               0.845373                         0.774157
# 12               0.815068                         0.804359
# 13               0.840165                         0.803390
# 14               0.827163                         0.813051
# 15               0.846603                         0.788044
# 16               0.814260                         0.806871
# 17               0.840796                         0.808349
# 18               0.822854                         0.819484
# 19               0.841950                         0.784948
# 20               0.814234                         0.810387
# 21               0.838172                         0.806878
# 22               0.823600                         0.819144
# 23               0.844223                         0.787462
# 24               0.822160                         0.811616
# 25               0.837493                         0.809632
# 26               0.827199                         0.816894
# 27               0.845347                         0.812001
# 28               0.824622                         0.812558
#
#     test/manhattan/roc_auc  data/num_train_samples
# 0                 0.847684                   80661
# 1                 0.833669                   80661
# 2                 0.849114                   80661
# 3                 0.833678                   80661
# 4                 0.845698                   80661
# 5                 0.848250                   80661
# 6                 0.834868                   80661
# 7                 0.820112                   80661
# 8                 0.842101                   80661
# 9                 0.832247                   80661
# 10                0.848926                   80661
# 11                0.813071                   80661
# 12                0.840232                   80661
# 13                0.830372                   80661
# 14                0.847014                   80661
# 15                0.816687                   80661
# 16                0.841560                   80661
# 17                0.829638                   80661
# 18                0.847556                   80661
# 19                0.812721                   80661
# 20                0.840092                   80661
# 21                0.832793                   80661
# 22                0.848885                   80661
# 23                0.811485                   80661
# 24                0.841466                   80661
# 25                0.831947                   80661
# 26                0.847246                   80661
# 27                0.836491                   80661
# 28                0.846500                   80661

# %%
stats.groupby(["pretrained", "finetuned"]).mean()
# Out:
#                       test/brooklyn/temporal_roc_auc  test/brooklyn/roc_auc  \
# pretrained finetuned
# all_sites  brooklyn                         0.812392               0.843851
#            manhattan                        0.791405               0.826459
# brooklyn   brooklyn                         0.796474               0.844525
#            manhattan                        0.787448               0.818017
# manhattan  brooklyn                         0.805489               0.839327
#            manhattan                        0.786353               0.825325
#
#                       test/manhattan/temporal_roc_auc  test/manhattan/roc_auc  \
# pretrained finetuned
# all_sites  brooklyn                          0.809947                0.834677
#            manhattan                         0.816095                0.847449
# brooklyn   brooklyn                          0.784578                0.814815
#            manhattan                         0.809092                0.841090
# manhattan  brooklyn                          0.806995                0.831399
#            manhattan                         0.817278                0.847925
#
#                       data/num_train_samples
# pretrained finetuned
# all_sites  brooklyn                  80661.0
#            manhattan                 80661.0
# brooklyn   brooklyn                  80661.0
#            manhattan                 80661.0
# manhattan  brooklyn                  80661.0
#            manhattan                 80661.0

# %%
stats.groupby(["pretrained", "finetuned"]).std()
# Out:
#                       test/brooklyn/temporal_roc_auc  test/brooklyn/roc_auc  \
# pretrained finetuned
# all_sites  brooklyn                         0.005466               0.002338
#            manhattan                        0.009203               0.003711
# brooklyn   brooklyn                         0.006916               0.001715
#            manhattan                        0.005622               0.004862
# manhattan  brooklyn                         0.002864               0.001416
#            manhattan                        0.002746               0.002013
#
#                       test/manhattan/temporal_roc_auc  test/manhattan/roc_auc  \
# pretrained finetuned
# all_sites  brooklyn                          0.001713                0.001335
#            manhattan                         0.003174                0.001363
# brooklyn   brooklyn                          0.005974                0.003539
#            manhattan                         0.003362                0.000883
# manhattan  brooklyn                          0.002338                0.001334
#            manhattan                         0.002582                0.000915
#
#                       data/num_train_samples
# pretrained finetuned
# all_sites  brooklyn                      0.0
#            manhattan                     0.0
# brooklyn   brooklyn                      0.0
#            manhattan                     0.0
# manhattan  brooklyn                      0.0
#            manhattan                     0.0
